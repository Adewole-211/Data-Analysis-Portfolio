# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
companies = pd.read_csv("Unicorn_Companies.csv")
companies.head()
# Out:
#      Company Valuation Date Joined                         Industry  \
# 0  Bytedance     $180B      4/7/17          Artificial intelligence
# 1     SpaceX     $100B     12/1/12                            Other
# 2      SHEIN     $100B      7/3/18  E-commerce & direct-to-consumer
# 3     Stripe      $95B     1/23/14                          Fintech
# 4     Klarna      $46B    12/12/11                          Fintech
#
#             City Country/Region      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012     $8B
# 1      Hawthorne  United States  North America          2002     $7B
# 2       Shenzhen          China           Asia          2008     $2B
# 3  San Francisco  United States  North America          2010     $2B
# 4      Stockholm         Sweden         Europe          2005     $4B
#
#                                     Select Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...
# ...

# %%
companies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   object
#  2   Date Joined       1074 non-null   object
#  3   Industry          1074 non-null   object
#  4   City              1058 non-null   object
#  5   Country/Region    1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year Founded      1074 non-null   int64
#  8   Funding           1074 non-null   object
#  9   Select Investors  1073 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 84.0+ KB

# %%
companies.dtypes
# Out:
# Company             object
# Valuation           object
# Date Joined         object
# Industry            object
# City                object
# Country/Region      object
# Continent           object
# Year Founded         int64
# Funding             object
# Select Investors    object
# dtype: object

# %%
companies['Date Joined'] = pd.to_datetime(companies["Date Joined"])
companies.dtypes
# Out:
# C:\Users\Adewole\AppData\Local\Temp\ipykernel_17940\3967289396.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   companies['Date Joined'] = pd.to_datetime(companies["Date Joined"])
# Company                     object
# Valuation                   object
# Date Joined         datetime64[ns]
# Industry                    object
# City                        object
# Country/Region              object
# Continent                   object
# Year Founded                 int64
# Funding                     object
# Select Investors            object
# dtype: object

# %%
companies["Year Joined"] = companies["Date Joined"].dt.year
companies['Years to Unicorn'] = companies["Year Joined"] - companies["Year Founded"]
companies.head()
# Out:
#      Company Valuation Date Joined                         Industry  \
# 0  Bytedance     $180B  2017-04-07          Artificial intelligence
# 1     SpaceX     $100B  2012-12-01                            Other
# 2      SHEIN     $100B  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe      $95B  2014-01-23                          Fintech
# 4     Klarna      $46B  2011-12-12                          Fintech
#
#             City Country/Region      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012     $8B
# 1      Hawthorne  United States  North America          2002     $7B
# 2       Shenzhen          China           Asia          2008     $2B
# 3  San Francisco  United States  North America          2010     $2B
# 4      Stockholm         Sweden         Europe          2005     $4B
#
#                                     Select Investors  Year Joined  \
# 0  Sequoia Capital China, SIG Asia Investments, S...         2017
# ...

# %%
companies.dtypes
# Out:
# Company                     object
# Valuation                   object
# Date Joined         datetime64[ns]
# Industry                    object
# City                        object
# Country/Region              object
# Continent                   object
# Year Founded                 int64
# Funding                     object
# Select Investors            object
# Year Joined                  int32
# Years to Unicorn             int64
# dtype: object

# %%
companies['Years to Unicorn'].describe(include= "all")
# Out:
# count    1074.000000
# mean        7.000931
# std         5.329672
# min        -4.000000
# 25%         4.000000
# 50%         6.000000
# 75%         9.000000
# max        98.000000
# Name: Years to Unicorn, dtype: float64

# %%
companies['Years to Unicorn'].nsmallest(20)
# Out:
# 714    -4
# 161     0
# 314     0
# 396     0
# 546     0
# 554     0
# 775     0
# 822     0
# 967     0
# 1001    0
# 26      1
# 33      1
# 52      1
# 78      1
# 94      1
# 102     1
# 127     1
# 151     1
# 226     1
# 238     1
# Name: Years to Unicorn, dtype: int64

# %%
companies[companies['Years to Unicorn'] < 0]
# Out:
#           Company Valuation Date Joined                     Industry     City  \
# 714  Yidian Zixun       $1B  2017-10-17  Mobile & telecommunications  Beijing
#
#     Country/Region Continent  Year Founded Funding  \
# 714          China      Asia          2021   $151M
#
#                                    Select Investors  Year Joined  \
# 714  Phoenix New Media, Tianjin Haihe Industry Fund         2017
#
#      Years to Unicorn
# 714                -4

# %%
companies.loc[companies['Company'] == 'Yidian Zixun']['Year Founded'] = 2011
# Out:
# C:\Users\Adewole\AppData\Local\Temp\ipykernel_17940\570604803.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   companies.loc[companies['Company'] == 'Yidian Zixun']['Year Founded'] = 2011

# %%
companies.loc[714, 'Year Founded'] =2011

# %%
companies[companies['Years to Unicorn'] < 0]
# Out:
#           Company Valuation Date Joined                     Industry     City  \
# 714  Yidian Zixun       $1B  2017-10-17  Mobile & telecommunications  Beijing
#
#     Country/Region Continent  Year Founded Funding  \
# 714          China      Asia          2011   $151M
#
#                                    Select Investors  Year Joined  \
# 714  Phoenix New Media, Tianjin Haihe Industry Fund         2017
#
#      Years to Unicorn
# 714                -4

# %%
companies['Years to Unicorn'] = companies["Year Joined"] - companies["Year Founded"]

# %%
companies['Years to Unicorn'].describe()
# Out:
# count    1074.000000
# mean        7.010242
# std         5.319160
# min         0.000000
# 25%         4.000000
# 50%         6.000000
# 75%         9.000000
# max        98.000000
# Name: Years to Unicorn, dtype: float64

# %%
industry_list = ['Artificial intelligence', 'Other','E-commerce & direct-to-consumer', 'Fintech',\
       'Internet software & services','Supply chain, logistics, & delivery', 'Consumer & retail',\
       'Data management & analytics', 'Edtech', 'Health', 'Hardware','Auto & transportation', \
        'Travel', 'Cybersecurity','Mobile & telecommunications']

# %%
industry_list
# Out:
# ['Artificial intelligence',
#  'Other',
#  'E-commerce & direct-to-consumer',
#  'Fintech',
#  'Internet software & services',
#  'Supply chain, logistics, & delivery',
#  'Consumer & retail',
#  'Data management & analytics',
#  'Edtech',
#  'Health',
#  'Hardware',
#  'Auto & transportation',
#  'Travel',
#  'Cybersecurity',
#  'Mobile & telecommunications']

# %%
companies["Industry"].value_counts()
# Out:
# Industry
# Fintech                                224
# Internet software & services           205
# E-commerce & direct-to-consumer        111
# Health                                  74
# Artificial intelligence                 73
# Other                                   58
# Supply chain, logistics, & delivery     57
# Cybersecurity                           50
# Data management & analytics             41
# Mobile & telecommunications             38
# Hardware                                34
# Auto & transportation                   31
# Edtech                                  28
# Consumer & retail                       25
# Travel                                  14
# Artificial Intelligence                 11
# Name: count, dtype: int64

# %%
set(companies['Industry']) - set(industry_list)
# Out:
# {'Artificial Intelligence'}

# %%
replacement_dict = {'Artificial Intelligence': 'Artificial intelligence',
                   'Data management and analytics': 'Data management & analytics',
                   'FinTech': 'Fintech'
                   }

# %%
companies['Industry'] = companies['Industry'].replace(replacement_dict)

# %%
set(companies["Industry"]) - set(industry_list)
# Out:
# set()

# %%
companies['Company'].duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1069    False
# 1070    False
# 1071    False
# 1072    False
# 1073    False
# Name: Company, Length: 1074, dtype: bool

# %%
companies['Company'].drop_duplicates( keep='first')
# Out:
# 0         Bytedance
# 1            SpaceX
# 2             SHEIN
# 3            Stripe
# 4            Klarna
#            ...
# 1069       Zhaogang
# 1070    Zhuan Zhuan
# 1071       Zihaiguo
# 1072           Zopa
# 1073          Zwift
# Name: Company, Length: 1073, dtype: object

# %%
def str_to_num(x): return int(x.strip('B$'))

# %%
companies['val_num'] = companies['Valuation'].apply(str_to_num)

# %%
companies['High Valuation'] = pd.qcut(
    companies['val_num'],
    2,
    labels = ['high', 'low'])

# %%
companies.head(20)
# Out:
#          Company Valuation Date Joined                             Industry  \
# 0      Bytedance     $180B  2017-04-07              Artificial intelligence
# 1         SpaceX     $100B  2012-12-01                                Other
# 2          SHEIN     $100B  2018-07-03      E-commerce & direct-to-consumer
# 3         Stripe      $95B  2014-01-23                              Fintech
# 4         Klarna      $46B  2011-12-12                              Fintech
# 5          Canva      $40B  2018-01-08         Internet software & services
# 6   Checkout.com      $40B  2019-05-02                              Fintech
# 7      Instacart      $39B  2014-12-30  Supply chain, logistics, & delivery
# 8      JUUL Labs      $38B  2017-12-20                    Consumer & retail
# 9     Databricks      $38B  2019-02-05          Data management & analytics
# 10       Revolut      $33B  2018-04-26                              Fintech
# ...

# %%
companies['Continent'].value_counts()
# Out:
# Continent
# North America    589
# Asia             310
# Europe           143
# South America     21
# Oceania            8
# Africa             3
# Name: count, dtype: int64

# %%
continent_dict = {'North America': 1,
                  'Asia': 2,
                  'Europe': 3,
                  'South America': 4,
                  'Oceania': 5,
                  'Africa': 6
                 }
companies['Continent Number'] = companies['Continent'].replace(continent_dict)
companies.head()
# Out:
# C:\Users\Adewole\AppData\Local\Temp\ipykernel_17940\1654871584.py:8: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   companies['Continent Number'] = companies['Continent'].replace(continent_dict)
#      Company Valuation Date Joined                         Industry  \
# 0  Bytedance     $180B  2017-04-07          Artificial intelligence
# 1     SpaceX     $100B  2012-12-01                            Other
# 2      SHEIN     $100B  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe      $95B  2014-01-23                          Fintech
# 4     Klarna      $46B  2011-12-12                          Fintech
#
#             City Country/Region      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012     $8B
# ...

# %%
companies['Country/Region Numeric'] = companies['Country/Region'].astype('category').cat.codes

# %%
companies.head()
# Out:
#      Company Valuation Date Joined                         Industry  \
# 0  Bytedance     $180B  2017-04-07          Artificial intelligence
# 1     SpaceX     $100B  2012-12-01                            Other
# 2      SHEIN     $100B  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe      $95B  2014-01-23                          Fintech
# 4     Klarna      $46B  2011-12-12                          Fintech
#
#             City Country/Region      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012     $8B
# 1      Hawthorne  United States  North America          2002     $7B
# 2       Shenzhen          China           Asia          2008     $2B
# 3  San Francisco  United States  North America          2010     $2B
# 4      Stockholm         Sweden         Europe          2005     $4B
#
#                                     Select Investors  Year Joined  \
# 0  Sequoia Capital China, SIG Asia Investments, S...         2017
# ...

# %%
industry_encoded = pd.get_dummies(companies['Industry'])
companies = pd.concat([companies, industry_encoded],axis = 1)

companies.head()
# Out:
#      Company Valuation Date Joined                         Industry  \
# 0  Bytedance     $180B  2017-04-07          Artificial intelligence
# 1     SpaceX     $100B  2012-12-01                            Other
# 2      SHEIN     $100B  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe      $95B  2014-01-23                          Fintech
# 4     Klarna      $46B  2011-12-12                          Fintech
#
#             City Country/Region      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012     $8B
# 1      Hawthorne  United States  North America          2002     $7B
# 2       Shenzhen          China           Asia          2008     $2B
# 3  San Francisco  United States  North America          2010     $2B
# 4      Stockholm         Sweden         Europe          2005     $4B
#
#                                     Select Investors  Year Joined  \
# 0  Sequoia Capital China, SIG Asia Investments, S...         2017
# ...
