# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime as dt
import plotly.express as px

# %%
df = pd.read_csv('Unicorn_Companies.csv')

# %%
df.head(10)
# Out:
#         Company Valuation Date Joined                             Industry  \
# 0     Bytedance     $180B      4/7/17              Artificial intelligence
# 1        SpaceX     $100B     12/1/12                                Other
# 2         SHEIN     $100B      7/3/18      E-commerce & direct-to-consumer
# 3        Stripe      $95B     1/23/14                              Fintech
# 4        Klarna      $46B    12/12/11                              Fintech
# 5         Canva      $40B      1/8/18         Internet software & services
# 6  Checkout.com      $40B      5/2/19                              Fintech
# 7     Instacart      $39B    12/30/14  Supply chain, logistics, & delivery
# 8     JUUL Labs      $38B    12/20/17                    Consumer & retail
# 9    Databricks      $38B      2/5/19          Data management & analytics
#
#             City  Country/Region      Continent  Year Founded Funding  \
# 0        Beijing           China           Asia          2012     $8B
# ...

# %%
df.shape
# Out:
# (1074, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   object
#  2   Date Joined       1074 non-null   object
#  3   Industry          1074 non-null   object
#  4   City              1058 non-null   object
#  5   Country/Region    1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year Founded      1074 non-null   int64
#  8   Funding           1074 non-null   object
#  9   Select Investors  1073 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 84.0+ KB

# %%
df.notnull()
# Out:
#       Company  Valuation  Date Joined  Industry  City  Country/Region  \
# 0        True       True         True      True  True            True
# 1        True       True         True      True  True            True
# 2        True       True         True      True  True            True
# 3        True       True         True      True  True            True
# 4        True       True         True      True  True            True
# ...       ...        ...          ...       ...   ...             ...
# 1069     True       True         True      True  True            True
# 1070     True       True         True      True  True            True
# 1071     True       True         True      True  True            True
# 1072     True       True         True      True  True            True
# 1073     True       True         True      True  True            True
#
#       Continent  Year Founded  Funding  Select Investors
# 0          True          True     True              True
# ...

# %%
df.describe()
# Out:
#        Year Founded
# count   1074.000000
# mean    2012.895717
# std        5.698573
# min     1919.000000
# 25%     2011.000000
# 50%     2014.000000
# 75%     2016.000000
# max     2021.000000

# %%
df['Date Joined'] = pd.to_datetime(df['Date Joined'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   object
#  2   Date Joined       1074 non-null   datetime64[ns]
#  3   Industry          1074 non-null   object
#  4   City              1058 non-null   object
#  5   Country/Region    1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year Founded      1074 non-null   int64
#  8   Funding           1074 non-null   object
#  9   Select Investors  1073 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 84.0+ KB
# ...

# %%
df['Year Joined'] = df['Date Joined'].dt.year
df.head()
# Out:
#      Company Valuation Date Joined                         Industry  \
# 0  Bytedance     $180B  2017-04-07          Artificial intelligence
# 1     SpaceX     $100B  2012-12-01                            Other
# 2      SHEIN     $100B  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe      $95B  2014-01-23                          Fintech
# 4     Klarna      $46B  2011-12-12                          Fintech
#
#             City Country/Region      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012     $8B
# 1      Hawthorne  United States  North America          2002     $7B
# 2       Shenzhen          China           Asia          2008     $2B
# 3  San Francisco  United States  North America          2010     $2B
# 4      Stockholm         Sweden         Europe          2005     $4B
#
#                                     Select Investors  Year Joined
# 0  Sequoia Capital China, SIG Asia Investments, S...         2017
# ...

# %%
def str_to_num(x): return int(x.strip('B$'))

# %%
df['valuation_num'] = df['Valuation'].apply(str_to_num)

# %%
df
# Out:
#           Company Valuation Date Joined                         Industry  \
# 0       Bytedance     $180B  2017-04-07          Artificial intelligence
# 1          SpaceX     $100B  2012-12-01                            Other
# 2           SHEIN     $100B  2018-07-03  E-commerce & direct-to-consumer
# 3          Stripe      $95B  2014-01-23                          Fintech
# 4          Klarna      $46B  2011-12-12                          Fintech
# ...           ...       ...         ...                              ...
# 1069     Zhaogang       $1B  2017-06-29  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan       $1B  2017-04-18  E-commerce & direct-to-consumer
# 1071     Zihaiguo       $1B  2021-05-06                Consumer & retail
# 1072         Zopa       $1B  2021-10-19                          Fintech
# 1073        Zwift       $1B  2020-09-16  E-commerce & direct-to-consumer
#
#                City  Country/Region      Continent  Year Founded Funding  \
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1069    False
# 1070    False
# 1071    False
# 1072    False
# 1073    False
# Length: 1074, dtype: bool

# %%
df.isna().sum()
# Out:
# Company              0
# Valuation            0
# Date Joined          0
# Industry             0
# City                16
# Country/Region       0
# Continent            0
# Year Founded         0
# Funding              0
# Select Investors     1
# Year Joined          0
# valuation_num        0
# dtype: int64

# %%
mask_df = df.isna()
mask_df
# Out:
#       Company  Valuation  Date Joined  Industry   City  Country/Region  \
# 0       False      False        False     False  False           False
# 1       False      False        False     False  False           False
# 2       False      False        False     False  False           False
# 3       False      False        False     False  False           False
# 4       False      False        False     False  False           False
# ...       ...        ...          ...       ...    ...             ...
# 1069    False      False        False     False  False           False
# 1070    False      False        False     False  False           False
# 1071    False      False        False     False  False           False
# 1072    False      False        False     False  False           False
# 1073    False      False        False     False  False           False
#
#       Continent  Year Founded  Funding  Select Investors  Year Joined  \
# ...

# %%
mask_df.any(axis=0)
# Out:
# Company             False
# Valuation           False
# Date Joined         False
# Industry            False
# City                 True
# Country/Region      False
# Continent           False
# Year Founded        False
# Funding             False
# Select Investors     True
# Year Joined         False
# valuation_num       False
# dtype: bool

# %%
mask_df.any(axis=1)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1069    False
# 1070    False
# 1071    False
# 1072    False
# 1073    False
# Length: 1074, dtype: bool

# %%
mask_df = mask_df.any(axis=1)

# %%
mask_df
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1069    False
# 1070    False
# 1071    False
# 1072    False
# 1073    False
# Length: 1074, dtype: bool

# %%
df_missing_row = df[mask_df]

# %%
df_missing_row.head(12)
# Out:
#                         Company Valuation Date Joined  \
# 12                          FTX      $32B  2021-07-20
# 170                   HyalRoute       $4B  2020-05-26
# 242                      Moglix       $3B  2021-05-17
# 251                        Trax       $3B  2019-07-22
# 325                 Amber Group       $3B  2021-06-21
# 382                   Ninja Van       $2B  2021-09-27
# 541  Advance Intelligence Group       $2B  2021-09-23
# 629            LinkSure Network       $1B  2015-01-01
# 811                   Carousell       $1B  2021-09-15
# 848                  Matrixport       $1B  2021-06-01
# 880                    bolttech       $1B  2021-07-01
# 889                       Carro       $1B  2021-06-14
#
#                                 Industry      City Country/Region  \
# 12                               Fintech       NaN        Bahamas
# 170          Mobile & telecommunications       NaN      Singapore
# ...

# %%
df_missing_row.value_counts('Country/Region')
# Out:
# Country/Region
# Singapore    12
# Hong Kong     3
# China         1
# Bahamas       1
# Name: count, dtype: int64

# %%
df_missing_row.shape
# Out:
# (17, 12)

# %%
count_total =  df.size
count_total
# Out:
# 12888

# %%
count_dropna_rows = df.dropna().size
count_dropna_rows
# Out:
# 12684

# %%
count_dropna_columns = df.dropna(axis="columns").size
count_dropna_columns
# Out:
# 10740

# %%
print(((count_total - count_dropna_columns)/count_total))
print()
print(((count_total - count_dropna_rows)/count_total))
# Out:
# 0.16666666666666666
#
# 0.015828677839851025

# %%
#From Exemplar and stackoverflow
column_perc = (((count_total - count_dropna_columns)/count_total))

row_perc = (((count_total - count_dropna_rows)/count_total))

print(f'Percentage removed, rows: {row_perc:.2%}')
print()
print(f'Percentage removed, columns: {column_perc:.2%}')
# Out:
# Percentage removed, rows: 1.58%
#
# Percentage removed, columns: 16.67%

# %%
df_backfill =  df.bfill() # newer method no longer fillna(method = backfill)
df_backfill.head()
# Out:
#      Company Valuation Date Joined                         Industry  \
# 0  Bytedance     $180B  2017-04-07          Artificial intelligence
# 1     SpaceX     $100B  2012-12-01                            Other
# 2      SHEIN     $100B  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe      $95B  2014-01-23                          Fintech
# 4     Klarna      $46B  2011-12-12                          Fintech
#
#             City Country/Region      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012     $8B
# 1      Hawthorne  United States  North America          2002     $7B
# 2       Shenzhen          China           Asia          2008     $2B
# 3  San Francisco  United States  North America          2010     $2B
# 4      Stockholm         Sweden         Europe          2005     $4B
#
#                                     Select Investors  Year Joined  \
# 0  Sequoia Capital China, SIG Asia Investments, S...         2017
# ...

# %%
df_missing_row.index
# Out:
# Index([  12,  170,  242,  251,  325,  382,  541,  629,  811,  848,  880,  889,
#         893,  980,  986,  994, 1061],
#       dtype='int64')

# %%
df_backfill.iloc[df_missing_row.index, :]
# Out:
#                          Company Valuation Date Joined  \
# 12                           FTX      $32B  2021-07-20
# 170                    HyalRoute       $4B  2020-05-26
# 242                       Moglix       $3B  2021-05-17
# 251                         Trax       $3B  2019-07-22
# 325                  Amber Group       $3B  2021-06-21
# 382                    Ninja Van       $2B  2021-09-27
# 541   Advance Intelligence Group       $2B  2021-09-23
# 629             LinkSure Network       $1B  2015-01-01
# 811                    Carousell       $1B  2021-09-15
# 848                   Matrixport       $1B  2021-06-01
# 880                     bolttech       $1B  2021-07-01
# 889                        Carro       $1B  2021-06-14
# 893                        Cider       $1B  2021-09-02
# 980                         NIUM       $1B  2021-07-13
# 986                          ONE       $1B  2021-12-08
# 994                      PatSnap       $1B  2021-03-16
# ...

# %%
hard_mask = ((df['Industry'] == 'Hardware') & (df['City'].isin(['Beijing' , 'San Francisco' ,'London'])))|((df['Industry'] == 'Artificial intelligence') & (df['City'] == 'London'))
hard_mask.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df_invest = df[hard_mask]
df_invest.head(10)
# Out:
#                   Company Valuation Date Joined                 Industry  \
# 36                Bitmain      $12B  2018-07-06                 Hardware
# 43          Global Switch      $11B  2016-12-22                 Hardware
# 147               Chipone       $5B  2021-12-16                 Hardware
# 845               Density       $1B  2021-11-10                 Hardware
# 873          BenevolentAI       $1B  2015-06-02  Artificial intelligence
# 923                 Geek+       $1B  2018-11-21                 Hardware
# 1040  TERMINUS Technology       $1B  2018-10-25                 Hardware
# 1046            Tractable       $1B  2021-06-16  Artificial intelligence
#
#                City  Country/Region      Continent  Year Founded Funding  \
# 36          Beijing           China           Asia          2015   $765M
# 43           London  United Kingdom         Europe          1998     $5B
# 147         Beijing           China           Asia          2008     $1B
# ...

# %%
national_valuations = df.groupby('Country/Region')['valuation_num'].sum().sort_values(ascending=False).reset_index()
national_valuations.head(15)
# Out:
#     Country/Region  valuation_num
# 0    United States           1933
# 1            China            696
# 2            India            196
# 3   United Kingdom            195
# 4          Germany             72
# 5           Sweden             63
# 6        Australia             56
# 7           France             55
# 8           Canada             49
# 9      South Korea             41
# 10          Israel             39
# 11          Brazil             37
# 12         Bahamas             32
# 13       Indonesia             28
# 14       Singapore             21

# %%
national_valuations_no_big4 = national_valuations.iloc[4:, :]

national_valuations_no_big4.head(10)
# Out:
#    Country/Region  valuation_num
# 4         Germany             72
# 5          Sweden             63
# 6       Australia             56
# 7          France             55
# 8          Canada             49
# 9     South Korea             41
# 10         Israel             39
# 11         Brazil             37
# 12        Bahamas             32
# 13      Indonesia             28

# %%
plt.figure(figsize=(15, 5));
sns.barplot( data = national_valuations_no_big4,
    x='Country/Region',
    y = 'valuation_num',
    hue = 'Country/Region'
);
plt.xticks(rotation=45, horizontalalignment='right')
plt.show()

# %%
data = national_valuations_no_big4

px.scatter_geo(data, 
               locations='Country/Region', 
               size='valuation_num', 
               locationmode='country names', 
               color='Country/Region',
               title='Total company valuations by country (non-big-four)')
# Out:
# C:\Users\Adewole\AppData\Local\Temp\ipykernel_22136\2215684087.py:3: DeprecationWarning: The library used by the *country names* `locationmode` option is changing in an upcoming version. Country names in existing plots may not work in the new version. To ensure consistent behavior, consider setting `locationmode` to *ISO-3*.
#   px.scatter_geo(data,
